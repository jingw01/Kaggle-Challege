# %% [markdown]
# # Bike Sharing Demand

# %% [markdown]
# Task:
#
# You are provided hourly rental data spanning two years. For this competition, the training set is comprised of the first 19 days of each month, while the test set is the 20th to the end of the month. You must predict the total count of bikes rented during each hour covered by the test set, using only information available prior to the rental period.
#
# Data:http://www.kaggle.com/c/bike-sharing-demand/data

# %% [markdown]
# #### Setup and Plotting code

# %%
#Source --- CS109; 

# %matplotlib inline
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl

import brewer2mpl
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_cmap = brewer2mpl.get_map('Dark2', 'Qualitative', 7)
dark2_colors = dark2_cmap.mpl_colors

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()
        
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
train=pd.read_csv("train.csv")

indext=pd.DatetimeIndex(train['datetime'].values)
train=train.reset_index(indext)
train['hour']=indext.hour
train['date']=indext.date
train['dayofweek']=indext.dayofweek
varlist=list(train.columns.values)
train.head()
# Out:
#    index             datetime  season  holiday  workingday  weather  temp   atemp  humidity  windspeed  casual  registered  count  hour        date  dayofweek
# 0      0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395        81          0       3          13     16     0  2011-01-01          5
# 1      1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635        80          0       8          32     40     1  2011-01-01          5
# 2      2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635        80          0       5          27     32     2  2011-01-01          5
# 3      3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395        75          0       3          10     13     3  2011-01-01          5
# 4      4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395        75          0       0           1      1     4  2011-01-01          5

# %% [markdown]
# #### Explore the data

# %%
#in group level, check whether there are correlation between some variables

from pandas.tools.plotting import scatter_matrix
fig=plt.figure()
time=range(24)
scatter_matrix(train[['weather','temp','atemp','humidity','windspeed','count']], diagonal="kde")
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x6D357E70>,
#         <matplotlib.axes.AxesSubplot object at 0x6D3CBF10>,
#         <matplotlib.axes.AxesSubplot object at 0x6D4996B0>,
#         <matplotlib.axes.AxesSubplot object at 0x6D4BDC30>,
#         <matplotlib.axes.AxesSubplot object at 0x6D636510>,
#         <matplotlib.axes.AxesSubplot object at 0x6D692CB0>],
#        [<matplotlib.axes.AxesSubplot object at 0x6D719730>,
#         <matplotlib.axes.AxesSubplot object at 0x6D78FD70>,
#         <matplotlib.axes.AxesSubplot object at 0x6D7B9310>,
#         <matplotlib.axes.AxesSubplot object at 0x6D831BD0>,
#         <matplotlib.axes.AxesSubplot object at 0x6D8722F0>,
#         <matplotlib.axes.AxesSubplot object at 0x6D925C30>],
#        [<matplotlib.axes.AxesSubplot object at 0x6D976210>,
#         <matplotlib.axes.AxesSubplot object at 0x6D941590>,
#         <matplotlib.axes.AxesSubplot object at 0x6DA585F0>,
#         <matplotlib.axes.AxesSubplot object at 0x6DA8CC90>,
#         <matplotlib.axes.AxesSubplot object at 0x6DAFD250>,
#         <matplotlib.axes.AxesSubplot object at 0x6DB71B10>],
#        [<matplotlib.axes.AxesSubplot object at 0x6DB93270>,
#         <matplotlib.axes.AxesSubplot object at 0x6DC13D30>,
#         <matplotlib.axes.AxesSubplot object at 0x6DC93390>,
#         <matplotlib.axes.AxesSubplot object at 0x6DCB4910>,
#         <matplotlib.axes.AxesSubplot object at 0x6DD761F0>,
#         <matplotlib.axes.AxesSubplot object at 0x6DDAB890>],
#        [<matplotlib.axes.AxesSubplot object at 0x6DDD9250>,
#         <matplotlib.axes.AxesSubplot object at 0x6DECE810>,
#         <matplotlib.axes.AxesSubplot object at 0x6DEAB610>,
#         <matplotlib.axes.AxesSubplot object at 0x6DFB2BF0>,
#         <matplotlib.axes.AxesSubplot object at 0x6E0122B0>,
#         <matplotlib.axes.AxesSubplot object at 0x6E035850>],
#        [<matplotlib.axes.AxesSubplot object at 0x6E105130>,
#         <matplotlib.axes.AxesSubplot object at 0x6E11EAF0>,
#         <matplotlib.axes.AxesSubplot object at 0x6E1A9350>,
#         <matplotlib.axes.AxesSubplot object at 0x6E21D990>,
#         <matplotlib.axes.AxesSubplot object at 0x6E23FF10>,
#         <matplotlib.axes.AxesSubplot object at 0x6E2817F0>]], dtype=object)

# %% [markdown]
# It seems that only atemp and windspeed have some effects on the count. Temperature between 20-30 or atemp around 30 tend to have more people biking. When the windspeed increases to more than 30, the count starts to drop.
#
# There are few things that we need to investigate before we research the conclusion:
#     - Because temperature and windspeed also tie to the time of a day, the drop may due to difference in time of a day.

# %%
#THERE ARE GAPS IN THE TIME SERIES;
ts=pd.Series(train['count'].values,index=index)
ts=ts.resample('H').fillna(0)
ts.plot()

# %%
tsd=ts.resample('M',how='mean')
tsd.plot()

# %% [markdown]
# When we plot the monthly total throughout the years, we can see an annually pattern and a general annual increase in the demand of bikes.

# %%
#Compare the distribution of counts across the same day of a month;

colns=['Jan','Feb','Mar','Apr','May','Jun','July','Aug','Sep','Oct','Nov','Dec']

for j in [1,5,10]:
    tsday=pd.DataFrame(columns=colns,index=range(25))
    # tsday['Jan']=ts[pd.datetime(2011,1,1):pd.datetime(2011,1,2)].values[:25]
    
    for i, mon in enumerate(colns):
        i=i+1
        tsday[mon]=ts[pd.datetime(2011,i,j):pd.datetime(2011,i,j+1)].values
    tsday.plot(title='The Plot of Day %s of a Month' %j,)

# %%
rkeys=[0,1]
rvals=['NonWorkday','WorkingDay']
rmap={e[0]:e[1] for e in zip(rkeys,rvals)}

from pandas.tools.plotting import parallel_coordinates
df=train[train.hour==11]
dfna=df[['season','workingday','casual','registered','count']]
dfna_norm=(dfna-dfna.mean())/(dfna.max()-dfna.min())
dfna_norm['workingday']=df['workingday'].map(lambda x:rmap[x])
parallel_coordinates(dfna_norm,'workingday', colors=[dark2_cmap.mpl_colormap(col) for col in [0.5,0.0]], alpha=0.05)

# %%
rkeys=[1,2,3,4]
rvals=['Spring','Summer','Fall','Winter']
rmap={e[0]:e[1] for e in zip(rkeys,rvals)}
df=train[train.hour==11]
dfna=df[['season','workingday','registered','count']]
dfna_norm=(dfna-dfna.mean())/(dfna.max()-dfna.min())
dfna_norm['season']=df['season'].map(lambda x:rmap[x])
parallel_coordinates(dfna_norm,'season', colors=[dark2_cmap.mpl_colormap(col) for col in [1.5,1.0,0.5,0.0]], alpha=0.05)

# %%
#Explore relationship on everyday level
day=train.groupby('date')
daysum=day['casual','registered','count'].sum()
sum_list=list(daysum.columns.values)
renamedict_sum={k:k+"_daysum" for k in sum_list}
daysum.rename(inplace=True,columns=renamedict_sum)
daymean=day.mean()
daymean=daymean.drop(['casual','registered','count'],axis=1)
mean_list=list(daymean.columns.values)
#renamedict_mean={k:k+"_daymean" for k in mean_list}
#daymean.rename(inplace=True,columns=renamedict_sum)
daydf=daysum.join(daymean)
daydf.head()
# Out:
#             casual_daysum  registered_daysum  count_daysum  index  season  holiday  workingday   weather       temp      atemp   humidity  windspeed       hour  dayofweek
# date
# 2011-01-01            331                654           985   11.5       1        0           0  1.583333  14.110833  18.181250  80.583333  10.749871  11.500000          5
# 2011-01-02            131                670           801   35.0       1        0           0  1.956522  14.902609  17.686957  69.608696  16.652122  11.782609          6
# 2011-01-03            120               1229          1349   57.5       1        0           1  1.000000   8.050909   9.470227  43.727273  16.636709  12.318182          0
# 2011-01-04            108               1454          1562   80.0       1        0           1  1.043478   8.200000  10.606087  59.043478  10.739809  11.869565          1
# 2011-01-05             82               1518          1600  103.0       1        0           1  1.000000   9.305217  11.463478  43.695652  12.522300  11.869565          2

# %%
fig=plt.figure()
time=range(24)
fig,axes=plt.subplots(figsize=(10,10),nrows=4, ncols=3)
axes[0][0].plot(daydf['casual_daysum'],daydf['season'],'.')
axes[1][0].plot(daydf['casual_daysum'],daydf['holiday'],'.')
axes[2][0].plot(daydf['casual_daysum'],daydf['workingday'],'.')
axes[3][0].plot(daydf['casual_daysum'],daydf['weather'],'.')
axes[0][1].plot(daydf['registered_daysum'],daydf['season'],'.')
axes[1][1].plot(daydf['registered_daysum'],daydf['holiday'],'.')
axes[2][1].plot(daydf['registered_daysum'],daydf['workingday'],'.')
axes[3][1].plot(daydf['registered_daysum'],daydf['weather'],'.')
axes[0][2].plot(daydf['count_daysum'],daydf['season'],'.')
axes[1][2].plot(daydf['count_daysum'],daydf['holiday'],'.')
axes[2][2].plot(daydf['count_daysum'],daydf['workingday'],'.')
axes[3][2].plot(daydf['count_daysum'],daydf['weather'],'.')

# %%
time=train.groupby('hour')
time.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 120 entries, (0, 0) to (23, 114)
# Data columns (total 13 columns):
# datetime      120  non-null values
# season        120  non-null values
# holiday       120  non-null values
# workingday    120  non-null values
# weather       120  non-null values
# temp          120  non-null values
# atemp         120  non-null values
# humidity      120  non-null values
# windspeed     120  non-null values
# casual        120  non-null values
# registered    120  non-null values
# count         120  non-null values
# hour          120  non-null values
# dtypes: float64(3), int32(1), int64(8), object(1)

# %%
dfrd=time.describe()
dfrd.head(20)
# Out:
#                 season     holiday  workingday     weather        temp       atemp    humidity   windspeed      casual  registered       count  hour
# hour
# 0    count  455.000000  455.000000  455.000000  455.000000  455.000000  455.000000  455.000000  455.000000  455.000000  455.000000  455.000000   455
#      mean     2.503297    0.028571    0.681319    1.393407   19.013187   22.462582   68.079121   10.701564   10.312088   44.826374   55.138462     0
#      std      1.118275    0.166782    0.466478    0.602089    7.197850    7.841370   16.659399    7.204139   10.756177   35.255433   43.620012     0
#      min      1.000000    0.000000    0.000000    1.000000    3.280000    3.030000    0.000000    0.000000    0.000000    0.000000    2.000000     0
#      25%      2.000000    0.000000    0.000000    1.000000   12.710000   15.910000   56.000000    6.003200    3.000000   20.000000   24.000000     0
#      50%      3.000000    0.000000    1.000000    1.000000   18.860000   22.725000   69.000000    8.998100    7.000000   33.000000   41.000000     0
#      75%      3.500000    0.000000    1.000000    2.000000   25.420000   29.167500   82.000000   15.001300   14.000000   62.000000   74.500000     0
#      max      4.000000    1.000000    1.000000    3.000000   33.620000   39.395000  100.000000   32.997500   68.000000  234.000000  283.000000     0
# 1    count  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000   454
#      mean     2.502203    0.028634    0.680617    1.431718   18.639648   22.011476   69.581498   10.418839    6.513216   27.345815   33.859031     1
#      std      1.119265    0.166961    0.466752    0.643156    7.217738    7.894625   16.262505    7.504129    7.889051   27.764728   34.112105     0
#      min      1.000000    0.000000    0.000000    1.000000    1.640000    1.515000    0.000000    0.000000    0.000000    0.000000    1.000000     1
#      25%      2.000000    0.000000    0.000000    1.000000   12.300000   15.150000   59.000000    6.003200    1.000000    8.000000   11.000000     1
#      50%      2.500000    0.000000    1.000000    1.000000   18.860000   22.725000   70.000000    8.998100    4.000000   15.000000   19.000000     1
#      75%      3.750000    0.000000    1.000000    2.000000   25.420000   28.790000   82.000000   15.001300    9.000000   38.000000   46.000000     1
#      max      4.000000    1.000000    1.000000    3.000000   33.620000   39.395000  100.000000   51.998700   49.000000  139.000000  168.000000     1
# 2    count  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000  448.000000   448
#      mean     2.522321    0.029018    0.680804    1.401786   18.455491   21.822623   70.622768   10.125315    4.819196   18.080357   22.899554     2
#      std      1.113047    0.168044    0.466686    0.619733    7.127096    7.772122   16.075552    7.509668    6.327094   21.083148   26.110267     0
#      min      1.000000    0.000000    0.000000    1.000000    0.820000    0.760000    0.000000    0.000000    0.000000    0.000000    1.000000     2

# %%
groupsum=train.groupby('hour')['casual','registered','count'].sum()
groupsum.head()
# Out:
#       casual  registered  count
# hour
# 0       4692       20396  25088
# 1       2957       12415  15372
# 2       2159        8100  10259
# 3       1161        3930   5091
# 4        558        2274   2832

# %%
groupmean=train.groupby('hour').mean()
groupmean=groupmean.drop(['casual','registered','count'],axis=1)

# %%
groupdf=groupmean.join(groupsum)
groupdf.head()
# Out:
#         season   holiday  workingday   weather       temp      atemp   humidity  windspeed  casual  registered  count
# hour
# 0     2.503297  0.028571    0.681319  1.393407  19.013187  22.462582  68.079121  10.701564    4692       20396  25088
# 1     2.502203  0.028634    0.680617  1.431718  18.639648  22.011476  69.581498  10.418839    2957       12415  15372
# 2     2.522321  0.029018    0.680804  1.401786  18.455491  21.822623  70.622768  10.125315    2159        8100  10259
# 3     2.556582  0.027714    0.667436  1.401848  18.433903  21.814007  72.293303  10.173416    1161        3930   5091
# 4     2.545249  0.029412    0.671946  1.427602  18.036290  21.352738  73.640271  10.717605     558        2274   2832

# %%
groupdf.shape
# Out:
# (24, 11)

# %%
fig=plt.figure()
time=range(24)
fig,axes=plt.subplots(figsize=(10,10),nrows=2, ncols=2)
axes[0][0].plot(time,groupdf['casual'],'.')
axes[0][1].plot(time,groupdf['registered'],'.')
axes[1][0].plot(time,groupdf['count'],'.')
axes[1][1].hist(groupdf['count'])
# Out:
# (array([ 5.,  3.,  1.,  2.,  4.,  4.,  2.,  1.,  0.,  2.]),
#  array([   2832. ,   23924.5,   45017. ,   66109.5,   87202. ,  108294.5,
#          129387. ,  150479.5,  171572. ,  192664.5,  213757. ]),
#  <a list of 10 Patch objects>)
