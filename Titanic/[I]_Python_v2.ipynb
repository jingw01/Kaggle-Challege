# %% [markdown]
# Getting Started with Pandas: Kaggle's Titanic Competition

# %%
import pandas as pd
import numpy as np

# For .read_csv, always use header=0 when you know row 0 is the header row
df = pd.read_csv('train.csv', header=0)

# %%
#Clean the data

#1. Use 0 or 1 to represent gender
df['Gender'] = df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
df['EmbarkedP']= df['Embarked'].dropna().map( {'S': 0, 'C': 1,'Q':2} ).astype(int)

# %%
#fill in the ages

median_ages = np.zeros((2,3))
for i in range(0, 2):
    for j in range(0, 3):
        median_ages[i,j] = df[(df['Gender'] == i) & \
                              (df['Pclass'] == j+1)]['Age'].dropna().median()
 
        
#Updata some of the rows for a column!!!**** 

df['AgeFill'] = df['Age']
for i in range(0, 2):
    for j in range(0, 3):
        df.loc[ (df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1),\
                'AgeFill'] = median_ages[i,j]

# %%
df[ df['Age'].isnull() ][['Gender','Pclass','Age','AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN     25.0
# 17       1       2  NaN     30.0
# 19       0       3  NaN     21.5
# 26       1       3  NaN     25.0
# 28       0       3  NaN     21.5
# 29       1       3  NaN     25.0
# 31       0       1  NaN     35.0
# 32       0       3  NaN     21.5
# 36       1       3  NaN     25.0
# 42       1       3  NaN     25.0

# %%
df['AgeIsNull'] = pd.isnull(df.Age).astype(int)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      Gender   EmbarkedP     AgeFill   AgeIsNull
# count  891.000000  891.000000  891.000000  889.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.647587    0.362205   29.112424    0.198653
# std      0.806057   49.693429    0.477990    0.636157   13.304424    0.399210
# ...

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']
df['Age*Class'] = df.AgeFill * df.Pclass

import pylab as plot
df['Age*Class'].hist()
plot.show()

# %%
#To use sklearn, need to convert dataframe to numpy

#Check variables that are objects:
df.dtypes[df.dtypes.map(lambda x: x=='object')]

#drop objects；
df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1) 

#drop rows with NAN

df = df.dropna()

#convert to new train data
train_data = df.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-097210acc263> in <module>()
#       5
#       6 #drop objects；
# ----> 7 df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)
#       8
#       9 #drop rows with NAN
#
# C:\Users\jwen\Anaconda\lib\site-packages\pandas\core\generic.pyc in drop(self, labels, axis, level)
#     402                 new_axis = axis.drop(labels, level=level)
#     403             else:
# --> 404                 new_axis = axis.drop(labels)
#     405             dropped = self.reindex(**{axis_name: new_axis})
#     406             try:
#
# C:\Users\jwen\Anaconda\lib\site-packages\pandas\core\index.pyc in drop(self, labels)
#    1305         mask = indexer == -1
#    1306         if mask.any():
# -> 1307             raise ValueError('labels %s not contained in axis' % labels[mask])
# ...
